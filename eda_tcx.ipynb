# %% [markdown]
# ### Load a TCX file, display and analyze

# %%
import pandas as pd

# maps
import folium

from utility import load_in_pandas_from_tcx, compute_total_distance

# %%
POWER = False
CADENCE = False

# %%
F_NAME = "luigi_activity_11448803267.tcx"

df = load_in_pandas_from_tcx(F_NAME, cadence=False, power=False, debug=False)

df['timestamp'] = pd.to_datetime(df['timestamp'])
# Out:
# Exception: time: 2023-06-29T07:31:13.000Z, 'NoneType' object has no attribute 'find'
# Exception: time: 2023-06-29T07:31:14.000Z, 'NoneType' object has no attribute 'find'
# Exception: time: 2023-06-29T08:15:32.000Z, 'NoneType' object has no attribute 'find'
# Exception: time: 2023-06-29T08:27:43.000Z, 'NoneType' object has no attribute 'find'
# Exception: time: 2023-06-29T08:27:44.000Z, 'NoneType' object has no attribute 'find'

# %%
df.head(10)
# Out:
#    id                 timestamp        position_lat       position_long  \
# 0   1 2023-06-29 07:08:51+00:00    41.8832397647202  12.475301558151841
# 1   2 2023-06-29 07:08:52+00:00  41.883262479677796  12.475279597565532
# 2   3 2023-06-29 07:08:57+00:00  41.883373288437724  12.475134255364537
# 3   4 2023-06-29 07:09:03+00:00   41.88352935947478  12.474955217912793
# 4   5 2023-06-29 07:09:04+00:00  41.883554589003325  12.474927809089422
# 5   6 2023-06-29 07:09:10+00:00   41.88367260619998  12.474807109683752
# 6   7 2023-06-29 07:09:12+00:00   41.88371107913554  12.474840972572565
# 7   8 2023-06-29 07:09:13+00:00   41.88372876495123  12.474874584004283
# 8   9 2023-06-29 07:09:14+00:00   41.88374628312886  12.474911883473396
# 9  10 2023-06-29 07:09:20+00:00  41.883869832381606  12.475104751065373
#
#    altitude  distance  speed  heart_rate
# 0      25.2       3.0   11.1       116.0
# 1      12.6       6.1   11.1       116.0
# 2      12.6      23.4   13.3       115.0
# 3      12.4      46.2   13.3       112.0
# 4      12.4      49.8   13.3       112.0
# 5      12.2      66.4    8.4       111.0
# 6      12.4      71.6   10.8       110.0
# 7      12.4      75.0   10.8       109.0
# 8      12.4      78.7   10.8       108.0
# 9      12.0      99.8   12.9       105.0

# %% [markdown]
# #### Compute Statistics

# %%
all_cols = df.columns
exc_cols = ['id','timestamp','position_lat','position_long']
allow_cols = list(set(all_cols) - set(exc_cols))

# ignored first row, with counts
pd.set_option('display.precision', 1)

df[allow_cols].describe()[1:]
# Out:
#       distance  speed  heart_rate  altitude
# mean   30461.1   23.5       135.4      10.2
# std    18820.5    6.8        10.4       5.1
# min        3.0    0.0        90.0      -1.2
# 25%    12985.9   20.8       130.0       7.8
# 50%    29897.7   25.7       137.0      12.6
# 75%    48443.0   28.1       143.0      13.8
# max    59817.2   40.5       160.0      25.2

# %%
# remove when lat, long are nan
df = df.dropna(ignore_index=True)

# time elapsed
time_diff = df['timestamp'].iloc[-1] - df['timestamp'].iloc[0]

print(f"Elapsed time: {time_diff}")

# tot km
tot_km = round(compute_total_distance(df)/1000., 2)

print(f"Tot km. travelled: {tot_km}")

# va aggiunto il metabolismo basale (sono solo le calorie portate ai pedali)
# enhanced using eff factor (default = 0.25)
# we're assuming time between points is 1 sec.
if POWER:
    print(f"Tot active cal. consumed: {compute_energy_consumed(df, 'power'):.0f} kcal.")
# Out:
# Elapsed time: 0 days 02:43:37
# Tot km. travelled: 59.82

# %%
# remove eventually rows where lat, lon are nan
df = df.dropna(ignore_index=True)

m = folium.Map(location=[df['position_lat'][1], df['position_long'][1]], zoom_start=15)

# to create the popup
cols_list = ['position_lat', 'position_long', 'altitude', 'speed', 'heart_rate']
if POWER:
    cols_list.append('power')
if CADENCE:
    cols_list.append('cadence')
    
for i, row in df[cols_list].iterrows():
    f_str = f"<b>Altitude: {row['altitude']:.1f} m.</b><br><b>Speed: {row['speed']:.1f} kmh</b><br><b>HR: {row['heart_rate']:.0f}</b>"

    if POWER:
        f_str += f"<br><b>Power: {row['power']} w."
    if CADENCE:
        f_str += f"<br><b>Cadence: {row['cadence']}"
        
    popup_html = folium.Popup(f_str, max_width=200)
    
    folium.CircleMarker(location=[row['position_lat'], row['position_long']],
                        popup=popup_html,
                        radius=3).add_to(m)

n_rows = i

# add start (green) end (red)
folium.CircleMarker(
    location=[df['position_lat'][0], df['position_long'][0]],  # Latitude and Longitude
    radius=5,  # Size of the circle
    color='green',  # Border color of the circle
    fill=True,
    fill_color='green'  # Fill color of the circle
).add_to(m)
folium.CircleMarker(
    location=[df['position_lat'][n_rows], df['position_long'][n_rows]],  # Latitude and Longitude
    radius=5,  # Size of the circle
    color='red',  # Border color of the circle
    fill=True,
    fill_color='red'  # Fill color of the circle
).add_to(m)

# display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_562b7ac258e0d7920ea30fed00cb2b21 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_562b7ac258e0d7920ea30fed00cb2b21&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_562b7ac258e0d7920ea30fed00cb2b21 = L.map(
#                 &quot;map_562b7ac258e0d7920ea30fed00cb2b21&quot;,
#                 {
#                     center: [41.883262479677796, 12.475279597565532],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3c9b5f60a8a73a7179d10698c124363c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_3c9b5f60a8a73a7179d10698c124363c.addTo(map_562b7ac258e0d7920ea30fed00cb2b21);
#
#             var circle_marker_0c1aff7125fa1471bac7f6a06a4bd7cb = L.circleMarker(
#                 [41.8832397647202, 12.475301558151841],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_562b7ac258e0d7920ea30fed00cb2b21);
#
#
#         var popup_2ab670868dfb4a0f819cb530cbd1daa8 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_860752d270a52602676decdbb0741030 = $(`&lt;div id=&quot;html_860752d270a52602676decdbb0741030&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Altitude: 25.2 m.&lt;/b&gt;&lt;br&gt;&lt;b&gt;Speed: 11.1 kmh&lt;/b&gt;&lt;br&gt;&lt;b&gt;HR: 116&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_2ab670868dfb4a0f819cb530cbd1daa8.setContent(html_860752d270a52602676decdbb0741030);
#
#
#
#         circle_marker_0c1aff7125fa1471bac7f6a06a4bd7cb.bindPopup(popup_2ab670868dfb4a0f819cb530cbd1daa8)
#         ;
#
#
#
#
#             var circle_marker_ad60aac12242ef182bada872fd110dc7 = L.circleMarker(
#                 [41.883262479677796, 12.475279597565532],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_562b7ac258e0d7920ea30fed00cb2b21);
#
#
#         var popup_e4c04b640754b9ca68771cf979ad1b0a = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_874bcf8a1e12b9da2ce017d70130b99f = $(`&lt;div id=&quot;html_874bcf8a1e12b9da2ce017d70130b99f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Altitude: 12.6 m.&lt;/b&gt;&lt;br&gt;&lt;b&gt;Speed: 11.1 kmh&lt;/b&gt;&lt;br&gt;&lt;b&gt;HR: 116&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_e4c04b640754b9ca68771cf979ad1b0a.setContent(html_874bcf8a1e12b9da2ce017d70130b99f);
#
#
#
#         circle_marker_ad60aac12242ef182bada872fd110dc7.bindPopup(popup_e4c04b640754b9ca68771cf979ad1b0a)
#         ;
#
#
#
#
#             var circle_marker_363c276ae469fae5bc8ad6a1f5822206 = L.circleMarker(
#                 [41.883373288437724, 12.475134255364537],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_562b7ac258e0d7920ea30fed00cb2b21);
#
#
#         var popup_55b512b146041bbe289dd53ab710c172 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_b5e9ce75ef15094e14414c26b842e7b7 = $(`&lt;div id=&quot;html_b5e9ce75ef15094e14414c26b842e7b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Altitude: 12.6 m.&lt;/b&gt;&lt;br&gt;&lt;b&gt;Speed: 13.3 kmh&lt;/b&gt;&lt;br&gt;&lt;b&gt;HR: 115&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_55b512b146041bbe289dd53ab710c172.setContent(html_b5e9ce75ef15094e14414c26b842e7b7);
